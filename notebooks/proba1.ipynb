# %%
import sys, os
project_root = r"C:/Users/Asia/Desktop/mocadr/MoviesRecommendations"
sys.path.insert(0, project_root)

from modules.utils import build_rating_matrix
import pandas as pd

data = pd.read_csv("C:/Users/Asia/Desktop/mocadr/MoviesRecommendations/data/ratings.csv")

print(data)
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
import sys, os
project_root = r"C:/Users/Asia/Desktop/mocadr/MoviesRecommendations"
sys.path.insert(0, project_root)

from modules.train import train_nmf_model, train_svd1_model
from modules.predict import predict
import pandas as pd

model = train_nmf_model("C:/Users/Asia/Desktop/mocadr/MoviesRecommendations/data/ratings.csv")

#train_svd1_model("C:/Users/Asia/Desktop/mocadr/project/MoviesRecomendation/data/ratings.csv")
# Out:
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# r: 6
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
z_approx, u, m = model
print(z_approx)
# Out:
# [[3.9287415 3.425532  3.314249  ... 3.5205967 3.5201228 4.0273585]
#  [3.9067004 3.4056935 3.29743   ... 3.497694  3.4985533 4.001162 ]
#  [3.9028347 3.401541  3.294764  ... 3.4899883 3.492512  3.9933476]
#  ...
#  [3.9000235 3.3986478 3.290444  ... 3.4888935 3.4889364 3.9735944]
#  [3.9059012 3.405115  3.296097  ... 3.4979625 3.498385  3.9993174]
#  [3.9465208 3.4396453 3.3310664 ... 3.5298004 3.5331726 4.0340056]]

# %%
import sys, os
project_root = r"C:/Users/Asia/Desktop/mocadr/MoviesRecommendations"
sys.path.insert(0, project_root)

from modules.predict import predict

pred = predict("C:/Users/Asia/Desktop/mocadr/MoviesRecommendations/data/sample_test.csv", model)

print(pred)
# Out:
#     userId  movieId  rating
# 0      432    77866     3.0
# 1      288      474     3.5
# 2      599     4351     3.0
# 3       42     2987     3.5
# 4       75     1610     4.0
# ..     ...      ...     ...
# 95     279   164179     4.0
# 96     428     6365     3.5
# 97     152      858     4.5
# 98     328     1198     4.0
# 99     427      435     2.5
#
# [100 rows x 3 columns]

# %%
test = pd.read_csv("C:/Users/Asia/Desktop/mocadr/MoviesRecommendations/data/sample_test_with_ratings.csv")
print(test)
# Out:
#     userId  movieId  rating
# 0      432    77866     4.5
# 1      288      474     3.0
# 2      599     4351     3.0
# 3       42     2987     4.0
# 4       75     1610     4.0
# ..     ...      ...     ...
# 95     279   164179     4.0
# 96     428     6365     3.0
# 97     152      858     5.0
# 98     328     1198     5.0
# 99     427      435     3.0
#
# [100 rows x 3 columns]

# %%
rss = (1 / len(test) * sum((pred["rating"] - test["rating"])**2))**(1/2)

print(rss)
# Out:
# 0.812403840463596

# %%
import sys, os
project_root = r"C:\Users\Asia\Desktop\mocadr\project\MoviesRecomendation"
sys.path.insert(0, project_root)

from modules.utils import build_rating_matrix

build_rating_matrix("C:/Users/Asia/Desktop/mocadr/project/MoviesRecomendation/data/ratings.csv")
# Out:
# (array([[4. , 3.4, 4. , ..., 3.5, 3.5, 4. ],
#         [3.9, 3.4, 3.3, ..., 3.5, 3.5, 4. ],
#         [3.9, 3.4, 3.3, ..., 3.5, 3.5, 4. ],
#         ...,
#         [2.5, 2. , 2. , ..., 3.5, 3.5, 4. ],
#         [3. , 3.4, 3.3, ..., 3.5, 3.5, 4. ],
#         [5. , 3.4, 3.3, ..., 3.5, 3.5, 4. ]],
#        shape=(610, 9724), dtype=float32),
#  {np.int64(1): 0,
#   np.int64(2): 1,
#   np.int64(3): 2,
#   np.int64(4): 3,
#   np.int64(5): 4,
#   np.int64(6): 5,
#   np.int64(7): 6,
#   np.int64(8): 7,
#   np.int64(9): 8,
#   np.int64(10): 9,
#   np.int64(11): 10,
#   np.int64(12): 11,
#   np.int64(13): 12,
#   np.int64(14): 13,
#   np.int64(15): 14,
#   np.int64(16): 15,
#   np.int64(17): 16,
#   np.int64(18): 17,
#   np.int64(19): 18,
#   np.int64(20): 19,
#   np.int64(21): 20,
#   np.int64(22): 21,
#   np.int64(23): 22,
#   np.int64(24): 23,
#   np.int64(25): 24,
#   np.int64(26): 25,
#   np.int64(27): 26,
#   np.int64(28): 27,
#   np.int64(29): 28,
#   np.int64(30): 29,
#   np.int64(31): 30,
#   np.int64(32): 31,
#   np.int64(33): 32,
#   np.int64(34): 33,
#   np.int64(35): 34,
#   np.int64(36): 35,
#   np.int64(37): 36,
#   np.int64(38): 37,
#   np.int64(39): 38,
#   np.int64(40): 39,
#   np.int64(41): 40,
#   np.int64(42): 41,
#   np.int64(43): 42,
#   np.int64(44): 43,
#   np.int64(45): 44,
#   np.int64(46): 45,
#   np.int64(47): 46,
#   np.int64(48): 47,
#   np.int64(49): 48,
#   np.int64(50): 49,
#   np.int64(51): 50,
#   np.int64(52): 51,
#   np.int64(53): 52,
#   np.int64(54): 53,
#   np.int64(55): 54,
#   np.int64(56): 55,
#   np.int64(57): 56,
#   np.int64(58): 57,
#   np.int64(59): 58,
#   np.int64(60): 59,
#   np.int64(61): 60,
#   np.int64(62): 61,
#   np.int64(63): 62,
#   np.int64(64): 63,
#   np.int64(65): 64,
#   np.int64(66): 65,
#   np.int64(67): 66,
#   np.int64(68): 67,
#   np.int64(69): 68,
#   np.int64(70): 69,
#   np.int64(71): 70,
#   np.int64(72): 71,
#   np.int64(73): 72,
#   np.int64(74): 73,
#   np.int64(75): 74,
#   np.int64(76): 75,
#   np.int64(77): 76,
#   np.int64(78): 77,
#   np.int64(79): 78,
#   np.int64(80): 79,
#   np.int64(81): 80,
#   np.int64(82): 81,
#   np.int64(83): 82,
#   np.int64(84): 83,
#   np.int64(85): 84,
#   np.int64(86): 85,
#   np.int64(87): 86,
#   np.int64(88): 87,
#   np.int64(89): 88,
#   np.int64(90): 89,
#   np.int64(91): 90,
#   np.int64(92): 91,
#   np.int64(93): 92,
#   np.int64(94): 93,
#   np.int64(95): 94,
#   np.int64(96): 95,
#   np.int64(97): 96,
#   np.int64(98): 97,
#   np.int64(99): 98,
#   np.int64(100): 99,
#   np.int64(101): 100,
#   np.int64(102): 101,
#   np.int64(103): 102,
#   np.int64(104): 103,
#   np.int64(105): 104,
#   np.int64(106): 105,
#   np.int64(107): 106,
#   np.int64(108): 107,
#   np.int64(109): 108,
#   np.int64(110): 109,
#   np.int64(111): 110,
#   np.int64(112): 111,
#   np.int64(113): 112,
#   np.int64(114): 113,
#   np.int64(115): 114,
#   np.int64(116): 115,
#   np.int64(117): 116,
#   np.int64(118): 117,
#   np.int64(119): 118,
#   np.int64(120): 119,
#   np.int64(121): 120,
#   np.int64(122): 121,
#   np.int64(123): 122,
#   np.int64(124): 123,
#   np.int64(125): 124,
#   np.int64(126): 125,
#   np.int64(127): 126,
#   np.int64(128): 127,
#   np.int64(129): 128,
#   np.int64(130): 129,
#   np.int64(131): 130,
#   np.int64(132): 131,
#   np.int64(133): 132,
#   np.int64(134): 133,
#   np.int64(135): 134,
#   np.int64(136): 135,
#   np.int64(137): 136,
#   np.int64(138): 137,
#   np.int64(139): 138,
#   np.int64(140): 139,
#   np.int64(141): 140,
#   np.int64(142): 141,
#   np.int64(143): 142,
#   np.int64(144): 143,
#   np.int64(145): 144,
#   np.int64(146): 145,
#   np.int64(147): 146,
#   np.int64(148): 147,
#   np.int64(149): 148,
#   np.int64(150): 149,
#   np.int64(151): 150,
#   np.int64(152): 151,
#   np.int64(153): 152,
#   np.int64(154): 153,
#   np.int64(155): 154,
#   np.int64(156): 155,
#   np.int64(157): 156,
#   np.int64(158): 157,
#   np.int64(159): 158,
#   np.int64(160): 159,
#   np.int64(161): 160,
#   np.int64(162): 161,
#   np.int64(163): 162,
#   np.int64(164): 163,
#   np.int64(165): 164,
#   np.int64(166): 165,
#   np.int64(167): 166,
#   np.int64(168): 167,
#   np.int64(169): 168,
#   np.int64(170): 169,
#   np.int64(171): 170,
#   np.int64(172): 171,
#   np.int64(173): 172,
#   np.int64(174): 173,
#   np.int64(175): 174,
#   np.int64(176): 175,
#   np.int64(177): 176,
#   np.int64(178): 177,
#   np.int64(179): 178,
#   np.int64(180): 179,
#   np.int64(181): 180,
#   np.int64(182): 181,
#   np.int64(183): 182,
#   np.int64(184): 183,
#   np.int64(185): 184,
#   np.int64(186): 185,
#   np.int64(187): 186,
#   np.int64(188): 187,
#   np.int64(189): 188,
#   np.int64(190): 189,
#   np.int64(191): 190,
#   np.int64(192): 191,
#   np.int64(193): 192,
#   np.int64(194): 193,
#   np.int64(195): 194,
#   np.int64(196): 195,
#   np.int64(197): 196,
#   np.int64(198): 197,
#   np.int64(199): 198,
#   np.int64(200): 199,
#   np.int64(201): 200,
#   np.int64(202): 201,
#   np.int64(203): 202,
#   np.int64(204): 203,
#   np.int64(205): 204,
#   np.int64(206): 205,
#   np.int64(207): 206,
#   np.int64(208): 207,
#   np.int64(209): 208,
#   np.int64(210): 209,
#   np.int64(211): 210,
#   np.int64(212): 211,
#   np.int64(213): 212,
#   np.int64(214): 213,
#   np.int64(215): 214,
#   np.int64(216): 215,
#   np.int64(217): 216,
#   np.int64(218): 217,
#   np.int64(219): 218,
#   np.int64(220): 219,
#   np.int64(221): 220,
#   np.int64(222): 221,
#   np.int64(223): 222,
#   np.int64(224): 223,
#   np.int64(225): 224,
#   np.int64(226): 225,
#   np.int64(227): 226,
#   np.int64(228): 227,
#   np.int64(229): 228,
#   np.int64(230): 229,
#   np.int64(231): 230,
#   np.int64(232): 231,
#   np.int64(233): 232,
#   np.int64(234): 233,
#   np.int64(235): 234,
#   np.int64(236): 235,
#   np.int64(237): 236,
#   np.int64(238): 237,
#   np.int64(239): 238,
#   np.int64(240): 239,
#   np.int64(241): 240,
#   np.int64(242): 241,
#   np.int64(243): 242,
#   np.int64(244): 243,
#   np.int64(245): 244,
#   np.int64(246): 245,
#   np.int64(247): 246,
#   np.int64(248): 247,
#   np.int64(249): 248,
#   np.int64(250): 249,
#   np.int64(251): 250,
#   np.int64(252): 251,
#   np.int64(253): 252,
#   np.int64(254): 253,
#   np.int64(255): 254,
#   np.int64(256): 255,
#   np.int64(257): 256,
#   np.int64(258): 257,
#   np.int64(259): 258,
#   np.int64(260): 259,
#   np.int64(261): 260,
#   np.int64(262): 261,
#   np.int64(263): 262,
#   np.int64(264): 263,
#   np.int64(265): 264,
#   np.int64(266): 265,
#   np.int64(267): 266,
#   np.int64(268): 267,
#   np.int64(269): 268,
#   np.int64(270): 269,
#   np.int64(271): 270,
#   np.int64(272): 271,
#   np.int64(273): 272,
#   np.int64(274): 273,
#   np.int64(275): 274,
#   np.int64(276): 275,
#   np.int64(277): 276,
#   np.int64(278): 277,
#   np.int64(279): 278,
#   np.int64(280): 279,
#   np.int64(281): 280,
#   np.int64(282): 281,
#   np.int64(283): 282,
#   np.int64(284): 283,
#   np.int64(285): 284,
#   np.int64(286): 285,
#   np.int64(287): 286,
#   np.int64(288): 287,
#   np.int64(289): 288,
#   np.int64(290): 289,
#   np.int64(291): 290,
#   np.int64(292): 291,
#   np.int64(293): 292,
#   np.int64(294): 293,
#   np.int64(295): 294,
#   np.int64(296): 295,
#   np.int64(297): 296,
#   np.int64(298): 297,
#   np.int64(299): 298,
#   np.int64(300): 299,
#   np.int64(301): 300,
#   np.int64(302): 301,
#   np.int64(303): 302,
#   np.int64(304): 303,
#   np.int64(305): 304,
#   np.int64(306): 305,
#   np.int64(307): 306,
#   np.int64(308): 307,
#   np.int64(309): 308,
#   np.int64(310): 309,
#   np.int64(311): 310,
#   np.int64(312): 311,
#   np.int64(313): 312,
#   np.int64(314): 313,
#   np.int64(315): 314,
#   np.int64(316): 315,
#   np.int64(317): 316,
#   np.int64(318): 317,
#   np.int64(319): 318,
#   np.int64(320): 319,
#   np.int64(321): 320,
#   np.int64(322): 321,
#   np.int64(323): 322,
#   np.int64(324): 323,
#   np.int64(325): 324,
#   np.int64(326): 325,
#   np.int64(327): 326,
#   np.int64(328): 327,
#   np.int64(329): 328,
#   np.int64(330): 329,
#   np.int64(331): 330,
#   np.int64(332): 331,
#   np.int64(333): 332,
#   np.int64(334): 333,
#   np.int64(335): 334,
#   np.int64(336): 335,
#   np.int64(337): 336,
#   np.int64(338): 337,
#   np.int64(339): 338,
#   np.int64(340): 339,
#   np.int64(341): 340,
#   np.int64(342): 341,
#   np.int64(343): 342,
#   np.int64(344): 343,
#   np.int64(345): 344,
#   np.int64(346): 345,
#   np.int64(347): 346,
#   np.int64(348): 347,
#   np.int64(349): 348,
#   np.int64(350): 349,
#   np.int64(351): 350,
#   np.int64(352): 351,
#   np.int64(353): 352,
#   np.int64(354): 353,
#   np.int64(355): 354,
#   np.int64(356): 355,
#   np.int64(357): 356,
#   np.int64(358): 357,
#   np.int64(359): 358,
#   np.int64(360): 359,
#   np.int64(361): 360,
#   np.int64(362): 361,
#   np.int64(363): 362,
#   np.int64(364): 363,
#   np.int64(365): 364,
#   np.int64(366): 365,
#   np.int64(367): 366,
#   np.int64(368): 367,
#   np.int64(369): 368,
#   np.int64(370): 369,
#   np.int64(371): 370,
#   np.int64(372): 371,
#   np.int64(373): 372,
#   np.int64(374): 373,
#   np.int64(375): 374,
#   np.int64(376): 375,
#   np.int64(377): 376,
#   np.int64(378): 377,
#   np.int64(379): 378,
#   np.int64(380): 379,
#   np.int64(381): 380,
#   np.int64(382): 381,
#   np.int64(383): 382,
#   np.int64(384): 383,
#   np.int64(385): 384,
#   np.int64(386): 385,
#   np.int64(387): 386,
#   np.int64(388): 387,
#   np.int64(389): 388,
#   np.int64(390): 389,
#   np.int64(391): 390,
#   np.int64(392): 391,
#   np.int64(393): 392,
#   np.int64(394): 393,
#   np.int64(395): 394,
#   np.int64(396): 395,
#   np.int64(397): 396,
#   np.int64(398): 397,
#   np.int64(399): 398,
#   np.int64(400): 399,
#   np.int64(401): 400,
#   np.int64(402): 401,
#   np.int64(403): 402,
#   np.int64(404): 403,
#   np.int64(405): 404,
#   np.int64(406): 405,
#   np.int64(407): 406,
#   np.int64(408): 407,
#   np.int64(409): 408,
#   np.int64(410): 409,
#   np.int64(411): 410,
#   np.int64(412): 411,
#   np.int64(413): 412,
#   np.int64(414): 413,
#   np.int64(415): 414,
#   np.int64(416): 415,
#   np.int64(417): 416,
#   np.int64(418): 417,
#   np.int64(419): 418,
#   np.int64(420): 419,
#   np.int64(421): 420,
#   np.int64(422): 421,
#   np.int64(423): 422,
#   np.int64(424): 423,
#   np.int64(425): 424,
#   np.int64(426): 425,
#   np.int64(427): 426,
#   np.int64(428): 427,
#   np.int64(429): 428,
#   np.int64(430): 429,
#   np.int64(431): 430,
#   np.int64(432): 431,
#   np.int64(433): 432,
#   np.int64(434): 433,
#   np.int64(435): 434,
#   np.int64(436): 435,
#   np.int64(437): 436,
#   np.int64(438): 437,
#   np.int64(439): 438,
#   np.int64(440): 439,
#   np.int64(441): 440,
#   np.int64(442): 441,
#   np.int64(443): 442,
#   np.int64(444): 443,
#   np.int64(445): 444,
#   np.int64(446): 445,
#   np.int64(447): 446,
#   np.int64(448): 447,
#   np.int64(449): 448,
#   np.int64(450): 449,
#   np.int64(451): 450,
#   np.int64(452): 451,
#   np.int64(453): 452,
#   np.int64(454): 453,
#   np.int64(455): 454,
#   np.int64(456): 455,
#   np.int64(457): 456,
#   np.int64(458): 457,
#   np.int64(459): 458,
#   np.int64(460): 459,
#   np.int64(461): 460,
#   np.int64(462): 461,
#   np.int64(463): 462,
#   np.int64(464): 463,
#   np.int64(465): 464,
#   np.int64(466): 465,
#   np.int64(467): 466,
#   np.int64(468): 467,
#   np.int64(469): 468,
#   np.int64(470): 469,
#   np.int64(471): 470,
#   np.int64(472): 471,
#   np.int64(473): 472,
#   np.int64(474): 473,
#   np.int64(475): 474,
#   np.int64(476): 475,
#   np.int64(477): 476,
#   np.int64(478): 477,
#   np.int64(479): 478,
#   np.int64(480): 479,
#   np.int64(481): 480,
#   np.int64(482): 481,
#   np.int64(483): 482,
#   np.int64(484): 483,
#   np.int64(485): 484,
#   np.int64(486): 485,
#   np.int64(487): 486,
#   np.int64(488): 487,
#   np.int64(489): 488,
#   np.int64(490): 489,
#   np.int64(491): 490,
#   np.int64(492): 491,
#   np.int64(493): 492,
#   np.int64(494): 493,
#   np.int64(495): 494,
#   np.int64(496): 495,
#   np.int64(497): 496,
#   np.int64(498): 497,
#   np.int64(499): 498,
#   np.int64(500): 499,
#   np.int64(501): 500,
#   np.int64(502): 501,
#   np.int64(503): 502,
#   np.int64(504): 503,
#   np.int64(505): 504,
#   np.int64(506): 505,
#   np.int64(507): 506,
#   np.int64(508): 507,
#   np.int64(509): 508,
#   np.int64(510): 509,
#   np.int64(511): 510,
#   np.int64(512): 511,
#   np.int64(513): 512,
#   np.int64(514): 513,
#   np.int64(515): 514,
#   np.int64(516): 515,
#   np.int64(517): 516,
#   np.int64(518): 517,
#   np.int64(519): 518,
#   np.int64(520): 519,
#   np.int64(521): 520,
#   np.int64(522): 521,
#   np.int64(523): 522,
#   np.int64(524): 523,
#   np.int64(525): 524,
#   np.int64(526): 525,
#   np.int64(527): 526,
#   np.int64(528): 527,
#   np.int64(529): 528,
#   np.int64(530): 529,
#   np.int64(531): 530,
#   np.int64(532): 531,
#   np.int64(533): 532,
#   np.int64(534): 533,
#   np.int64(535): 534,
#   np.int64(536): 535,
#   np.int64(537): 536,
#   np.int64(538): 537,
#   np.int64(539): 538,
#   np.int64(540): 539,
#   np.int64(541): 540,
#   np.int64(542): 541,
#   np.int64(543): 542,
#   np.int64(544): 543,
#   np.int64(545): 544,
#   np.int64(546): 545,
#   np.int64(547): 546,
#   np.int64(548): 547,
#   np.int64(549): 548,
#   np.int64(550): 549,
#   np.int64(551): 550,
#   np.int64(552): 551,
#   np.int64(553): 552,
#   np.int64(554): 553,
#   np.int64(555): 554,
#   np.int64(556): 555,
#   np.int64(557): 556,
#   np.int64(558): 557,
#   np.int64(559): 558,
#   np.int64(560): 559,
#   np.int64(561): 560,
#   np.int64(562): 561,
#   np.int64(563): 562,
#   np.int64(564): 563,
#   np.int64(565): 564,
#   np.int64(566): 565,
#   np.int64(567): 566,
#   np.int64(568): 567,
#   np.int64(569): 568,
#   np.int64(570): 569,
#   np.int64(571): 570,
#   np.int64(572): 571,
#   np.int64(573): 572,
#   np.int64(574): 573,
#   np.int64(575): 574,
#   np.int64(576): 575,
#   np.int64(577): 576,
#   np.int64(578): 577,
#   np.int64(579): 578,
#   np.int64(580): 579,
#   np.int64(581): 580,
#   np.int64(582): 581,
#   np.int64(583): 582,
#   np.int64(584): 583,
#   np.int64(585): 584,
#   np.int64(586): 585,
#   np.int64(587): 586,
#   np.int64(588): 587,
#   np.int64(589): 588,
#   np.int64(590): 589,
#   np.int64(591): 590,
#   np.int64(592): 591,
#   np.int64(593): 592,
#   np.int64(594): 593,
#   np.int64(595): 594,
#   np.int64(596): 595,
#   np.int64(597): 596,
#   np.int64(598): 597,
#   np.int64(599): 598,
#   np.int64(600): 599,
#   np.int64(601): 600,
#   np.int64(602): 601,
#   np.int64(603): 602,
#   np.int64(604): 603,
#   np.int64(605): 604,
#   np.int64(606): 605,
#   np.int64(607): 606,
#   np.int64(608): 607,
#   np.int64(609): 608,
#   np.int64(610): 609},
#  {np.int64(1): 0,
#   np.int64(2): 1,
#   np.int64(3): 2,
#   np.int64(4): 3,
#   np.int64(5): 4,
#   np.int64(6): 5,
#   np.int64(7): 6,
#   np.int64(8): 7,
#   np.int64(9): 8,
#   np.int64(10): 9,
#   np.int64(11): 10,
#   np.int64(12): 11,
#   np.int64(13): 12,
#   np.int64(14): 13,
#   np.int64(15): 14,
#   np.int64(16): 15,
#   np.int64(17): 16,
#   np.int64(18): 17,
#   np.int64(19): 18,
#   np.int64(20): 19,
#   np.int64(21): 20,
#   np.int64(22): 21,
#   np.int64(23): 22,
#   np.int64(24): 23,
#   np.int64(25): 24,
#   np.int64(26): 25,
#   np.int64(27): 26,
#   np.int64(28): 27,
#   np.int64(29): 28,
#   np.int64(30): 29,
#   np.int64(31): 30,
#   np.int64(32): 31,
#   np.int64(34): 32,
#   np.int64(36): 33,
#   np.int64(38): 34,
#   np.int64(39): 35,
#   np.int64(40): 36,
#   np.int64(41): 37,
#   np.int64(42): 38,
#   np.int64(43): 39,
#   np.int64(44): 40,
#   np.int64(45): 41,
#   np.int64(46): 42,
#   np.int64(47): 43,
#   np.int64(48): 44,
#   np.int64(49): 45,
#   np.int64(50): 46,
#   np.int64(52): 47,
#   np.int64(53): 48,
#   np.int64(54): 49,
#   np.int64(55): 50,
#   np.int64(57): 51,
#   np.int64(58): 52,
#   np.int64(60): 53,
#   np.int64(61): 54,
#   np.int64(62): 55,
#   np.int64(63): 56,
#   np.int64(64): 57,
#   np.int64(65): 58,
#   np.int64(66): 59,
#   np.int64(68): 60,
#   np.int64(69): 61,
#   np.int64(70): 62,
#   np.int64(71): 63,
#   np.int64(72): 64,
#   np.int64(73): 65,
#   np.int64(74): 66,
#   np.int64(75): 67,
#   np.int64(76): 68,
#   np.int64(77): 69,
#   np.int64(78): 70,
#   np.int64(79): 71,
#   np.int64(80): 72,
#   np.int64(81): 73,
#   np.int64(82): 74,
#   np.int64(83): 75,
#   np.int64(85): 76,
#   np.int64(86): 77,
#   np.int64(87): 78,
#   np.int64(88): 79,
#   np.int64(89): 80,
#   np.int64(92): 81,
#   np.int64(93): 82,
#   np.int64(94): 83,
#   np.int64(95): 84,
#   np.int64(96): 85,
#   np.int64(97): 86,
#   np.int64(99): 87,
#   np.int64(100): 88,
#   np.int64(101): 89,
#   np.int64(102): 90,
#   np.int64(103): 91,
#   np.int64(104): 92,
#   np.int64(105): 93,
#   np.int64(106): 94,
#   np.int64(107): 95,
#   np.int64(108): 96,
#   np.int64(110): 97,
#   np.int64(111): 98,
#   np.int64(112): 99,
#   np.int64(113): 100,
#   np.int64(116): 101,
#   np.int64(117): 102,
#   np.int64(118): 103,
#   np.int64(119): 104,
#   np.int64(121): 105,
#   np.int64(122): 106,
#   np.int64(123): 107,
#   np.int64(125): 108,
#   np.int64(126): 109,
#   np.int64(128): 110,
#   np.int64(129): 111,
#   np.int64(132): 112,
#   np.int64(135): 113,
#   np.int64(137): 114,
#   np.int64(140): 115,
#   np.int64(141): 116,
#   np.int64(144): 117,
#   np.int64(145): 118,
#   np.int64(146): 119,
#   np.int64(147): 120,
#   np.int64(148): 121,
#   np.int64(149): 122,
#   np.int64(150): 123,
#   np.int64(151): 124,
#   np.int64(152): 125,
#   np.int64(153): 126,
#   np.int64(154): 127,
#   np.int64(155): 128,
#   np.int64(156): 129,
#   np.int64(157): 130,
#   np.int64(158): 131,
#   np.int64(159): 132,
#   np.int64(160): 133,
#   np.int64(161): 134,
#   np.int64(162): 135,
#   np.int64(163): 136,
#   np.int64(164): 137,
#   np.int64(165): 138,
#   np.int64(166): 139,
#   np.int64(168): 140,
#   np.int64(169): 141,
#   np.int64(170): 142,
#   np.int64(171): 143,
#   np.int64(172): 144,
#   np.int64(173): 145,
#   np.int64(174): 146,
#   np.int64(175): 147,
#   np.int64(176): 148,
#   np.int64(177): 149,
#   np.int64(178): 150,
#   np.int64(179): 151,
#   np.int64(180): 152,
#   np.int64(181): 153,
#   np.int64(183): 154,
#   np.int64(184): 155,
#   np.int64(185): 156,
#   np.int64(186): 157,
#   np.int64(187): 158,
#   np.int64(188): 159,
#   np.int64(189): 160,
#   np.int64(190): 161,
#   np.int64(191): 162,
#   np.int64(193): 163,
#   np.int64(194): 164,
#   np.int64(195): 165,
#   np.int64(196): 166,
#   np.int64(198): 167,
#   np.int64(199): 168,
#   np.int64(201): 169,
#   np.int64(202): 170,
#   np.int64(203): 171,
#   np.int64(204): 172,
#   np.int64(205): 173,
#   np.int64(206): 174,
#   np.int64(207): 175,
#   np.int64(208): 176,
#   np.int64(209): 177,
#   np.int64(210): 178,
#   np.int64(211): 179,
#   np.int64(212): 180,
#   np.int64(213): 181,
#   np.int64(214): 182,
#   np.int64(215): 183,
#   np.int64(216): 184,
#   np.int64(217): 185,
#   np.int64(218): 186,
#   np.int64(219): 187,
#   np.int64(220): 188,
#   np.int64(222): 189,
#   np.int64(223): 190,
#   np.int64(224): 191,
#   np.int64(225): 192,
#   np.int64(227): 193,
#   np.int64(228): 194,
#   np.int64(229): 195,
#   np.int64(230): 196,
#   np.int64(231): 197,
#   np.int64(232): 198,
#   np.int64(233): 199,
#   np.int64(234): 200,
#   np.int64(235): 201,
#   np.int64(236): 202,
#   np.int64(237): 203,
#   np.int64(238): 204,
#   np.int64(239): 205,
#   np.int64(240): 206,
#   np.int64(241): 207,
#   np.int64(242): 208,
#   np.int64(243): 209,
#   np.int64(246): 210,
#   np.int64(247): 211,
#   np.int64(248): 212,
#   np.int64(249): 213,
#   np.int64(250): 214,
#   np.int64(251): 215,
#   np.int64(252): 216,
#   np.int64(253): 217,
#   np.int64(254): 218,
#   np.int64(255): 219,
#   np.int64(256): 220,
#   np.int64(257): 221,
#   np.int64(258): 222,
#   np.int64(259): 223,
#   np.int64(260): 224,
#   np.int64(261): 225,
#   np.int64(262): 226,
#   np.int64(263): 227,
#   np.int64(265): 228,
#   np.int64(266): 229,
#   np.int64(267): 230,
#   np.int64(269): 231,
#   np.int64(270): 232,
#   np.int64(271): 233,
#   np.int64(272): 234,
#   np.int64(273): 235,
#   np.int64(274): 236,
#   np.int64(275): 237,
#   np.int64(276): 238,
#   np.int64(277): 239,
#   np.int64(278): 240,
#   np.int64(279): 241,
#   np.int64(280): 242,
#   np.int64(281): 243,
#   np.int64(282): 244,
#   np.int64(283): 245,
#   np.int64(284): 246,
#   np.int64(285): 247,
#   np.int64(287): 248,
#   np.int64(288): 249,
#   np.int64(289): 250,
#   np.int64(290): 251,
#   np.int64(291): 252,
#   np.int64(292): 253,
#   np.int64(293): 254,
#   np.int64(294): 255,
#   np.int64(295): 256,
#   np.int64(296): 257,
#   np.int64(298): 258,
#   np.int64(299): 259,
#   np.int64(300): 260,
#   np.int64(301): 261,
#   np.int64(302): 262,
#   np.int64(303): 263,
#   np.int64(304): 264,
#   np.int64(305): 265,
#   np.int64(306): 266,
#   np.int64(307): 267,
#   np.int64(308): 268,
#   np.int64(310): 269,
#   np.int64(311): 270,
#   np.int64(312): 271,
#   np.int64(313): 272,
#   np.int64(314): 273,
#   np.int64(315): 274,
#   np.int64(316): 275,
#   np.int64(317): 276,
#   np.int64(318): 277,
#   np.int64(319): 278,
#   np.int64(320): 279,
#   np.int64(321): 280,
#   np.int64(322): 281,
#   np.int64(324): 282,
#   np.int64(325): 283,
#   np.int64(326): 284,
#   np.int64(327): 285,
#   np.int64(328): 286,
#   np.int64(329): 287,
#   np.int64(330): 288,
#   np.int64(331): 289,
#   np.int64(332): 290,
#   np.int64(333): 291,
#   np.int64(334): 292,
#   np.int64(335): 293,
#   np.int64(336): 294,
#   np.int64(337): 295,
#   np.int64(338): 296,
#   np.int64(339): 297,
#   np.int64(340): 298,
#   np.int64(341): 299,
#   np.int64(342): 300,
#   np.int64(343): 301,
#   np.int64(344): 302,
#   np.int64(345): 303,
#   np.int64(346): 304,
#   np.int64(347): 305,
#   np.int64(348): 306,
#   np.int64(349): 307,
#   np.int64(350): 308,
#   np.int64(351): 309,
#   np.int64(352): 310,
#   np.int64(353): 311,
#   np.int64(354): 312,
#   np.int64(355): 313,
#   np.int64(356): 314,
#   np.int64(357): 315,
#   np.int64(358): 316,
#   np.int64(359): 317,
#   np.int64(360): 318,
#   np.int64(361): 319,
#   np.int64(362): 320,
#   np.int64(363): 321,
#   np.int64(364): 322,
#   np.int64(365): 323,
#   np.int64(366): 324,
#   np.int64(367): 325,
#   np.int64(368): 326,
#   np.int64(369): 327,
#   np.int64(370): 328,
#   np.int64(371): 329,
#   np.int64(372): 330,
#   np.int64(373): 331,
#   np.int64(374): 332,
#   np.int64(376): 333,
#   np.int64(377): 334,
#   np.int64(378): 335,
#   np.int64(379): 336,
#   np.int64(380): 337,
#   np.int64(381): 338,
#   np.int64(382): 339,
#   np.int64(383): 340,
#   np.int64(384): 341,
#   np.int64(385): 342,
#   np.int64(386): 343,
#   np.int64(387): 344,
#   np.int64(388): 345,
#   np.int64(389): 346,
#   np.int64(390): 347,
#   np.int64(391): 348,
#   np.int64(393): 349,
#   np.int64(405): 350,
#   np.int64(406): 351,
#   np.int64(407): 352,
#   np.int64(408): 353,
#   np.int64(409): 354,
#   np.int64(410): 355,
#   np.int64(412): 356,
#   np.int64(413): 357,
#   np.int64(414): 358,
#   np.int64(415): 359,
#   np.int64(416): 360,
#   np.int64(417): 361,
#   np.int64(418): 362,
#   np.int64(419): 363,
#   np.int64(420): 364,
#   np.int64(421): 365,
#   np.int64(422): 366,
#   np.int64(423): 367,
#   np.int64(424): 368,
#   np.int64(425): 369,
#   np.int64(426): 370,
#   np.int64(427): 371,
#   np.int64(428): 372,
#   np.int64(429): 373,
#   np.int64(430): 374,
#   np.int64(431): 375,
#   np.int64(432): 376,
#   np.int64(433): 377,
#   np.int64(434): 378,
#   np.int64(435): 379,
#   np.int64(436): 380,
#   np.int64(437): 381,
#   np.int64(438): 382,
#   np.int64(440): 383,
#   np.int64(441): 384,
#   np.int64(442): 385,
#   np.int64(444): 386,
#   np.int64(445): 387,
#   np.int64(446): 388,
#   np.int64(448): 389,
#   np.int64(449): 390,
#   np.int64(450): 391,
#   np.int64(451): 392,
#   np.int64(452): 393,
#   np.int64(453): 394,
#   np.int64(454): 395,
#   np.int64(455): 396,
#   np.int64(456): 397,
#   np.int64(457): 398,
#   np.int64(458): 399,
#   np.int64(459): 400,
#   np.int64(460): 401,
#   np.int64(461): 402,
#   np.int64(464): 403,
#   np.int64(466): 404,
#   np.int64(467): 405,
#   np.int64(468): 406,
#   np.int64(469): 407,
#   np.int64(470): 408,
#   np.int64(471): 409,
#   np.int64(472): 410,
#   np.int64(473): 411,
#   np.int64(474): 412,
#   np.int64(475): 413,
#   np.int64(476): 414,
#   np.int64(477): 415,
#   np.int64(478): 416,
#   np.int64(479): 417,
#   np.int64(480): 418,
#   np.int64(481): 419,
#   np.int64(482): 420,
#   np.int64(484): 421,
#   np.int64(485): 422,
#   np.int64(486): 423,
#   np.int64(487): 424,
#   np.int64(488): 425,
#   np.int64(489): 426,
#   np.int64(490): 427,
#   np.int64(491): 428,
#   np.int64(492): 429,
#   np.int64(493): 430,
#   np.int64(494): 431,
#   np.int64(495): 432,
#   np.int64(496): 433,
#   np.int64(497): 434,
#   np.int64(499): 435,
#   np.int64(500): 436,
#   np.int64(501): 437,
#   np.int64(502): 438,
#   np.int64(504): 439,
#   np.int64(505): 440,
#   np.int64(506): 441,
#   np.int64(507): 442,
#   np.int64(508): 443,
#   np.int64(509): 444,
#   np.int64(510): 445,
#   np.int64(511): 446,
#   np.int64(512): 447,
#   np.int64(513): 448,
#   np.int64(514): 449,
#   np.int64(515): 450,
#   np.int64(516): 451,
#   np.int64(517): 452,
#   np.int64(518): 453,
#   np.int64(519): 454,
#   np.int64(520): 455,
#   np.int64(521): 456,
#   np.int64(522): 457,
#   np.int64(523): 458,
#   np.int64(524): 459,
#   np.int64(526): 460,
#   np.int64(527): 461,
#   np.int64(528): 462,
#   np.int64(529): 463,
#   np.int64(531): 464,
#   np.int64(532): 465,
#   np.int64(533): 466,
#   np.int64(534): 467,
#   np.int64(535): 468,
#   np.int64(536): 469,
#   np.int64(537): 470,
#   np.int64(538): 471,
#   np.int64(539): 472,
#   np.int64(540): 473,
#   np.int64(541): 474,
#   np.int64(542): 475,
#   np.int64(543): 476,
#   np.int64(544): 477,
#   np.int64(546): 478,
#   np.int64(547): 479,
#   np.int64(548): 480,
#   np.int64(549): 481,
#   np.int64(550): 482,
#   np.int64(551): 483,
#   np.int64(552): 484,
#   np.int64(553): 485,
#   np.int64(555): 486,
#   np.int64(556): 487,
#   np.int64(558): 488,
#   np.int64(562): 489,
#   np.int64(563): 490,
#   np.int64(564): 491,
#   np.int64(567): 492,
#   np.int64(568): 493,
#   np.int64(569): 494,
#   np.int64(573): 495,
#   np.int64(574): 496,
#   np.int64(575): 497,
#   np.int64(577): 498,
#   np.int64(579): 499,
#   np.int64(580): 500,
#   np.int64(581): 501,
#   np.int64(583): 502,
#   np.int64(585): 503,
#   np.int64(586): 504,
#   np.int64(587): 505,
#   np.int64(588): 506,
#   np.int64(589): 507,
#   np.int64(590): 508,
#   np.int64(592): 509,
#   np.int64(593): 510,
#   np.int64(594): 511,
#   np.int64(595): 512,
#   np.int64(596): 513,
#   np.int64(597): 514,
#   np.int64(599): 515,
#   np.int64(600): 516,
#   np.int64(602): 517,
#   np.int64(605): 518,
#   np.int64(606): 519,
#   np.int64(608): 520,
#   np.int64(609): 521,
#   np.int64(610): 522,
#   np.int64(611): 523,
#   np.int64(612): 524,
#   np.int64(613): 525,
#   np.int64(615): 526,
#   np.int64(616): 527,
#   np.int64(617): 528,
#   np.int64(618): 529,
#   np.int64(619): 530,
#   np.int64(626): 531,
#   np.int64(627): 532,
#   np.int64(628): 533,
#   np.int64(631): 534,
#   np.int64(632): 535,
#   np.int64(633): 536,
#   np.int64(634): 537,
#   np.int64(635): 538,
#   np.int64(636): 539,
#   np.int64(637): 540,
#   np.int64(638): 541,
#   np.int64(639): 542,
#   np.int64(640): 543,
#   np.int64(645): 544,
#   np.int64(647): 545,
#   np.int64(648): 546,
#   np.int64(649): 547,
#   np.int64(650): 548,
#   np.int64(653): 549,
#   np.int64(656): 550,
#   np.int64(661): 551,
#   np.int64(662): 552,
#   np.int64(663): 553,
#   np.int64(665): 554,
#   np.int64(667): 555,
#   np.int64(668): 556,
#   np.int64(670): 557,
#   np.int64(671): 558,
#   np.int64(673): 559,
#   np.int64(674): 560,
#   np.int64(678): 561,
#   np.int64(679): 562,
#   np.int64(680): 563,
#   np.int64(685): 564,
#   np.int64(688): 565,
#   np.int64(691): 566,
#   np.int64(692): 567,
#   np.int64(694): 568,
#   np.int64(695): 569,
#   np.int64(697): 570,
#   np.int64(698): 571,
#   np.int64(700): 572,
#   np.int64(703): 573,
#   np.int64(704): 574,
#   np.int64(706): 575,
#   np.int64(707): 576,
#   np.int64(708): 577,
#   np.int64(709): 578,
#   np.int64(710): 579,
#   np.int64(711): 580,
#   np.int64(714): 581,
#   np.int64(715): 582,
#   np.int64(718): 583,
#   np.int64(719): 584,
#   np.int64(720): 585,
#   np.int64(722): 586,
#   np.int64(724): 587,
#   np.int64(725): 588,
#   np.int64(726): 589,
#   np.int64(728): 590,
#   np.int64(731): 591,
#   np.int64(733): 592,
#   np.int64(735): 593,
#   np.int64(736): 594,
#   np.int64(737): 595,
#   np.int64(741): 596,
#   np.int64(742): 597,
#   np.int64(743): 598,
#   np.int64(745): 599,
#   np.int64(747): 600,
#   np.int64(748): 601,
#   np.int64(750): 602,
#   np.int64(757): 603,
#   np.int64(759): 604,
#   np.int64(760): 605,
#   np.int64(761): 606,
#   np.int64(762): 607,
#   np.int64(764): 608,
#   np.int64(765): 609,
#   np.int64(766): 610,
#   np.int64(773): 611,
#   np.int64(775): 612,
#   np.int64(778): 613,
#   np.int64(779): 614,
#   np.int64(780): 615,
#   np.int64(781): 616,
#   np.int64(782): 617,
#   np.int64(783): 618,
#   np.int64(784): 619,
#   np.int64(785): 620,
#   np.int64(786): 621,
#   np.int64(788): 622,
#   np.int64(790): 623,
#   np.int64(791): 624,
#   np.int64(795): 625,
#   np.int64(798): 626,
#   np.int64(799): 627,
#   np.int64(800): 628,
#   np.int64(801): 629,
#   np.int64(802): 630,
#   np.int64(803): 631,
#   np.int64(804): 632,
#   np.int64(805): 633,
#   np.int64(806): 634,
#   np.int64(808): 635,
#   np.int64(809): 636,
#   np.int64(810): 637,
#   np.int64(813): 638,
#   np.int64(818): 639,
#   np.int64(823): 640,
#   np.int64(824): 641,
#   np.int64(828): 642,
#   np.int64(829): 643,
#   np.int64(830): 644,
#   np.int64(832): 645,
#   np.int64(833): 646,
#   np.int64(835): 647,
#   np.int64(836): 648,
#   np.int64(837): 649,
#   np.int64(838): 650,
#   np.int64(839): 651,
#   np.int64(840): 652,
#   np.int64(841): 653,
#   np.int64(842): 654,
#   np.int64(848): 655,
#   np.int64(849): 656,
#   np.int64(851): 657,
#   np.int64(852): 658,
#   np.int64(858): 659,
#   np.int64(861): 660,
#   np.int64(866): 661,
#   np.int64(867): 662,
#   np.int64(869): 663,
#   np.int64(870): 664,
#   np.int64(875): 665,
#   np.int64(876): 666,
#   np.int64(879): 667,
#   np.int64(880): 668,
#   np.int64(881): 669,
#   np.int64(882): 670,
#   np.int64(885): 671,
#   np.int64(886): 672,
#   np.int64(888): 673,
#   np.int64(889): 674,
#   np.int64(891): 675,
#   np.int64(892): 676,
#   np.int64(893): 677,
#   np.int64(896): 678,
#   np.int64(897): 679,
#   np.int64(898): 680,
#   np.int64(899): 681,
#   np.int64(900): 682,
#   np.int64(901): 683,
#   np.int64(902): 684,
#   np.int64(903): 685,
#   np.int64(904): 686,
#   np.int64(905): 687,
#   np.int64(906): 688,
#   np.int64(907): 689,
#   np.int64(908): 690,
#   np.int64(909): 691,
#   np.int64(910): 692,
#   np.int64(911): 693,
#   np.int64(912): 694,
#   np.int64(913): 695,
#   np.int64(914): 696,
#   np.int64(915): 697,
#   np.int64(916): 698,
#   np.int64(917): 699,
#   np.int64(918): 700,
#   np.int64(919): 701,
#   np.int64(920): 702,
#   np.int64(921): 703,
#   np.int64(922): 704,
#   np.int64(923): 705,
#   np.int64(924): 706,
#   np.int64(926): 707,
#   np.int64(927): 708,
#   np.int64(928): 709,
#   np.int64(929): 710,
#   np.int64(930): 711,
#   np.int64(931): 712,
#   np.int64(932): 713,
#   np.int64(933): 714,
#   np.int64(934): 715,
#   np.int64(935): 716,
#   np.int64(936): 717,
#   np.int64(937): 718,
#   np.int64(938): 719,
#   np.int64(940): 720,
#   np.int64(941): 721,
#   np.int64(942): 722,
#   np.int64(943): 723,
#   np.int64(944): 724,
#   np.int64(945): 725,
#   np.int64(946): 726,
#   np.int64(947): 727,
#   np.int64(948): 728,
#   np.int64(949): 729,
#   np.int64(950): 730,
#   np.int64(951): 731,
#   np.int64(952): 732,
#   np.int64(953): 733,
#   np.int64(954): 734,
#   np.int64(955): 735,
#   np.int64(956): 736,
#   np.int64(959): 737,
#   np.int64(961): 738,
#   np.int64(963): 739,
#   np.int64(965): 740,
#   np.int64(968): 741,
#   np.int64(969): 742,
#   np.int64(970): 743,
#   np.int64(971): 744,
#   np.int64(973): 745,
#   np.int64(976): 746,
#   np.int64(979): 747,
#   np.int64(981): 748,
#   np.int64(982): 749,
#   np.int64(984): 750,
#   np.int64(986): 751,
#   np.int64(987): 752,
#   np.int64(988): 753,
#   np.int64(990): 754,
#   np.int64(991): 755,
#   np.int64(993): 756,
#   np.int64(994): 757,
#   np.int64(996): 758,
#   np.int64(998): 759,
#   np.int64(999): 760,
#   np.int64(1003): 761,
#   np.int64(1004): 762,
#   np.int64(1005): 763,
#   np.int64(1006): 764,
#   np.int64(1007): 765,
#   np.int64(1008): 766,
#   np.int64(1009): 767,
#   np.int64(1010): 768,
#   np.int64(1011): 769,
#   np.int64(1012): 770,
#   np.int64(1013): 771,
#   np.int64(1014): 772,
#   np.int64(1015): 773,
#   np.int64(1016): 774,
#   np.int64(1017): 775,
#   np.int64(1018): 776,
#   np.int64(1019): 777,
#   np.int64(1020): 778,
#   np.int64(1021): 779,
#   np.int64(1022): 780,
#   np.int64(1023): 781,
#   np.int64(1024): 782,
#   np.int64(1025): 783,
#   np.int64(1027): 784,
#   np.int64(1028): 785,
#   np.int64(1029): 786,
#   np.int64(1030): 787,
#   np.int64(1031): 788,
#   np.int64(1032): 789,
#   np.int64(1033): 790,
#   np.int64(1034): 791,
#   np.int64(1035): 792,
#   np.int64(1036): 793,
#   np.int64(1037): 794,
#   np.int64(1040): 795,
#   np.int64(1041): 796,
#   np.int64(1042): 797,
#   np.int64(1043): 798,
#   np.int64(1046): 799,
#   np.int64(1047): 800,
#   np.int64(1049): 801,
#   np.int64(1050): 802,
#   np.int64(1051): 803,
#   np.int64(1053): 804,
#   np.int64(1054): 805,
#   np.int64(1055): 806,
#   np.int64(1056): 807,
#   np.int64(1057): 808,
#   np.int64(1059): 809,
#   np.int64(1060): 810,
#   np.int64(1061): 811,
#   np.int64(1064): 812,
#   np.int64(1066): 813,
#   np.int64(1068): 814,
#   np.int64(1073): 815,
#   np.int64(1077): 816,
#   np.int64(1078): 817,
#   np.int64(1079): 818,
#   np.int64(1080): 819,
#   np.int64(1081): 820,
#   np.int64(1082): 821,
#   np.int64(1083): 822,
#   np.int64(1084): 823,
#   np.int64(1085): 824,
#   np.int64(1086): 825,
#   np.int64(1088): 826,
#   np.int64(1089): 827,
#   np.int64(1090): 828,
#   np.int64(1091): 829,
#   np.int64(1092): 830,
#   np.int64(1093): 831,
#   np.int64(1094): 832,
#   np.int64(1095): 833,
#   np.int64(1096): 834,
#   np.int64(1097): 835,
#   np.int64(1099): 836,
#   np.int64(1100): 837,
#   np.int64(1101): 838,
#   np.int64(1103): 839,
#   np.int64(1104): 840,
#   np.int64(1105): 841,
#   np.int64(1107): 842,
#   np.int64(1111): 843,
#   np.int64(1112): 844,
#   np.int64(1114): 845,
#   np.int64(1116): 846,
#   np.int64(1117): 847,
#   np.int64(1119): 848,
#   np.int64(1120): 849,
#   np.int64(1121): 850,
#   np.int64(1123): 851,
#   np.int64(1124): 852,
#   np.int64(1125): 853,
#   np.int64(1126): 854,
#   np.int64(1127): 855,
#   np.int64(1128): 856,
#   np.int64(1129): 857,
#   np.int64(1130): 858,
#   np.int64(1131): 859,
#   np.int64(1132): 860,
#   np.int64(1135): 861,
#   np.int64(1136): 862,
#   np.int64(1137): 863,
#   np.int64(1140): 864,
#   np.int64(1144): 865,
#   np.int64(1147): 866,
#   np.int64(1148): 867,
#   np.int64(1150): 868,
#   np.int64(1151): 869,
#   np.int64(1156): 870,
#   np.int64(1161): 871,
#   np.int64(1162): 872,
#   np.int64(1163): 873,
#   np.int64(1167): 874,
#   np.int64(1170): 875,
#   np.int64(1171): 876,
#   np.int64(1172): 877,
#   np.int64(1173): 878,
#   np.int64(1175): 879,
#   np.int64(1176): 880,
#   np.int64(1177): 881,
#   np.int64(1178): 882,
#   np.int64(1179): 883,
#   np.int64(1180): 884,
#   np.int64(1183): 885,
#   np.int64(1184): 886,
#   np.int64(1185): 887,
#   np.int64(1186): 888,
#   np.int64(1187): 889,
#   np.int64(1188): 890,
#   np.int64(1189): 891,
#   np.int64(1190): 892,
#   np.int64(1191): 893,
#   np.int64(1192): 894,
#   np.int64(1193): 895,
#   np.int64(1194): 896,
#   np.int64(1196): 897,
#   np.int64(1197): 898,
#   np.int64(1198): 899,
#   np.int64(1199): 900,
#   np.int64(1200): 901,
#   np.int64(1201): 902,
#   np.int64(1202): 903,
#   np.int64(1203): 904,
#   np.int64(1204): 905,
#   np.int64(1206): 906,
#   np.int64(1207): 907,
#   np.int64(1208): 908,
#   np.int64(1209): 909,
#   np.int64(1210): 910,
#   np.int64(1211): 911,
#   np.int64(1212): 912,
#   np.int64(1213): 913,
#   np.int64(1214): 914,
#   np.int64(1215): 915,
#   np.int64(1216): 916,
#   np.int64(1217): 917,
#   np.int64(1218): 918,
#   np.int64(1219): 919,
#   np.int64(1220): 920,
#   np.int64(1221): 921,
#   np.int64(1222): 922,
#   np.int64(1223): 923,
#   np.int64(1224): 924,
#   np.int64(1225): 925,
#   np.int64(1226): 926,
#   np.int64(1227): 927,
#   np.int64(1228): 928,
#   np.int64(1230): 929,
#   np.int64(1231): 930,
#   np.int64(1232): 931,
#   np.int64(1233): 932,
#   np.int64(1234): 933,
#   np.int64(1235): 934,
#   np.int64(1236): 935,
#   np.int64(1237): 936,
#   np.int64(1238): 937,
#   np.int64(1240): 938,
#   np.int64(1241): 939,
#   np.int64(1242): 940,
#   np.int64(1243): 941,
#   np.int64(1244): 942,
#   np.int64(1245): 943,
#   np.int64(1246): 944,
#   np.int64(1247): 945,
#   np.int64(1248): 946,
#   np.int64(1249): 947,
#   np.int64(1250): 948,
#   np.int64(1251): 949,
#   np.int64(1252): 950,
#   np.int64(1253): 951,
#   np.int64(1254): 952,
#   np.int64(1255): 953,
#   np.int64(1256): 954,
#   np.int64(1257): 955,
#   np.int64(1258): 956,
#   np.int64(1259): 957,
#   np.int64(1260): 958,
#   np.int64(1261): 959,
#   np.int64(1262): 960,
#   np.int64(1263): 961,
#   np.int64(1264): 962,
#   np.int64(1265): 963,
#   np.int64(1266): 964,
#   np.int64(1267): 965,
#   np.int64(1268): 966,
#   np.int64(1269): 967,
#   np.int64(1270): 968,
#   np.int64(1271): 969,
#   np.int64(1272): 970,
#   np.int64(1273): 971,
#   np.int64(1274): 972,
#   np.int64(1275): 973,
#   np.int64(1276): 974,
#   np.int64(1277): 975,
#   np.int64(1278): 976,
#   np.int64(1279): 977,
#   np.int64(1280): 978,
#   np.int64(1281): 979,
#   np.int64(1282): 980,
#   np.int64(1283): 981,
#   np.int64(1284): 982,
#   np.int64(1285): 983,
#   np.int64(1286): 984,
#   np.int64(1287): 985,
#   np.int64(1288): 986,
#   np.int64(1289): 987,
#   np.int64(1290): 988,
#   np.int64(1291): 989,
#   np.int64(1292): 990,
#   np.int64(1293): 991,
#   np.int64(1295): 992,
#   np.int64(1296): 993,
#   np.int64(1297): 994,
#   np.int64(1298): 995,
#   np.int64(1299): 996,
#   np.int64(1300): 997,
#   np.int64(1301): 998,
#   np.int64(1302): 999,
#   ...})

# %%
pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\asia\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kneed) (2.4.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\asia\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from kneed) (1.17.1)
# Downloading kneed-0.8.6-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys, os
project_root = r"C:/Users/Asia/Desktop/mocadr/MoviesRecommendations"
sys.path.insert(0, project_root)

from modules.utils import build_rating_matrix
import numpy as np
from sklearn.decomposition import NMF
import matplotlib.pyplot as plt
from kneed import KneeLocator, find_shape
from sklearn.model_selection import KFold

Z, user_map, movie_map = build_rating_matrix("C:/Users/Asia/Desktop/mocadr/MoviesRecommendations/data/ratings.csv")

kf = KFold(n_splits=5, shuffle=True, random_state=42)

n = 3
Z_approx = 0
rss = []



while n <= 13:
    n_rss = []
    for train_idx, test_idx in kf.split(df):
        train = Z.iloc[train_idx]
        model = NMF(n_components=n, init='random', random_state=0, max_iter=1000)
        W = model.fit_transform(train)
        H = model.components_
        train_approx = np.dot(W, H)
        test_users = [user_map[i] for i in test_idx]
        n_rss.append(np.sum((Z.iloc[test_idx] - )**2))
        print(n)
        n += 1

plt.plot(range(3, n), mse)
# Out:
# 3
# 4
# 5
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 6
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 7
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 8
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 9
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 10
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 11
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# 12
# 13
# c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\decomposition\_nmf.py:1720: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
data[[1],:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:174, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '([1], slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data[[1],:]
#
# File c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
# -> 3653     self._check_indexing_error(key)
#    3654     raise
#
# File c:\Users\Asia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:6094, in Index._check_indexing_error(self, key)
#    6090 def _check_indexing_error(self, key) -> None:
#    6091     if not is_scalar(key):
#    6092         # if key is not a scalar, directly raise an error (the code below
#    6093         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6094         raise InvalidIndexError(key)
#
# InvalidIndexError: ([1], slice(None, None, None))

# %%
import numpy as np
np.linspace(1, len(data), 6)
# Out:
# array([1.00000e+00, 2.01680e+04, 4.03350e+04, 6.05020e+04, 8.06690e+04,
#        1.00836e+05])

# %%
diff = []
for i in range(n - 4):
    diff.append(mse[i+1] - mse[i])

print(np.mean(diff))

plt.plot(range(3, n-1), diff)
# Out:
# -1244.196

# %%
diff_diff = []
for i in range(n - 3):
    diff_diff.append(abs(diff[i+1] - diff[i]))

print(np.median(diff_diff))

plt.plot(range(1, n-2), diff_diff)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 diff_diff = []
#       2 for i in range(n - 3):
# ----> 3     diff_diff.append(abs(diff[i+1] - diff[i]))
#       5 print(np.median(diff_diff))
#       7 plt.plot(range(1, n-2), diff_diff)
#
# IndexError: list index out of range

# %%
np.mean(diff_diff)
# Out:
# np.float32(1308.3237)
