# %%
import sys, os
project_root = r"C:\Users\Asia\Desktop\mocadr\project\MoviesRecomendation"
sys.path.insert(0, project_root)

from modules.train import train_nmf_model
import pandas as pd

train_nmf_model("C:/Users/Asia/Desktop/mocadr/project/MoviesRecomendation/data/ratings.csv")
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 5
#     from modules.train import train_nmf_model
#
#   File ~\Desktop\mocadr\project\MoviesRecomendation\modules\train.py:37
#     return Z_approx, user_map, movie_map
#     ^
# SyntaxError: 'return' outside function
